# %%
import mnist_loader
from network import Network, Sigmoid, CrossEntropyCost

# %% [markdown]
# # Load the MNIST data

# %%
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()

# %% [markdown]
# # Initialize the network

# %%
net = Network([784, 30, 10], cost=CrossEntropyCost, activation=Sigmoid)

# %% [markdown]
# # Train

# %%
net.SGD(training_data, epochs=30, mini_batch_size=10, eta=0.5, lmbda=5.0, evaluation_data=validation_data)
# Out:
# Epoch 0 training: Eval Accuracy: 94.42% | Eval Loss: 0.7905
# Epoch 1 training: Eval Accuracy: 95.23% | Eval Loss: 0.8531
# Epoch 2 training: Eval Accuracy: 95.17% | Eval Loss: 0.8921
# Epoch 3 training: Eval Accuracy: 95.02% | Eval Loss: 0.9179
# Epoch 4 training: Eval Accuracy: 95.39% | Eval Loss: 0.9286
# Epoch 5 training: Eval Accuracy: 95.15% | Eval Loss: 0.9504
# Epoch 6 training: Eval Accuracy: 95.59% | Eval Loss: 0.9297
# Epoch 7 training: Eval Accuracy: 95.30% | Eval Loss: 0.9511
# Epoch 8 training: Eval Accuracy: 95.80% | Eval Loss: 0.9497
# Epoch 9 training: Eval Accuracy: 95.64% | Eval Loss: 0.9607
# Epoch 10 training: Eval Accuracy: 95.37% | Eval Loss: 0.9639
# Epoch 11 training: Eval Accuracy: 95.66% | Eval Loss: 0.9588
# Epoch 12 training: Eval Accuracy: 95.66% | Eval Loss: 0.9553
# Epoch 13 training: Eval Accuracy: 95.66% | Eval Loss: 0.9604
# Epoch 14 training: Eval Accuracy: 95.92% | Eval Loss: 0.9503
# Epoch 15 training: Eval Accuracy: 95.91% | Eval Loss: 0.9516
# ...

# %% [markdown]
# # Plot Performance

# %%
net.plot_performance()

# %% [markdown]
# # Save Weights and Bias

# %%
net.save("baseline_mnist_model.json")
